# %% [markdown]
# <a href="https://colab.research.google.com/github/nalgo-intern/test2/blob/test/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
hello = "Hello"
print(f'{hello}.')
# Out:
# Hello.
